# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maalaaikaa/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ### My Lane: Content Refresh Prioritization
#
# I chose the **Content Refresh Prioritization** lane because content teams often manage many pages and cannot update all of them at once. This project focuses on identifying which pages should be reviewed first based on their historical performance and content-related metrics. By using data to prioritize pages for refresh, the recommendations can help content teams use their time more efficiently and support better decision-making. I selected this lane because it addresses a practical business problem and provides an opportunity to apply machine learning to real-world data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### The Question: Decision, Action, Cost of a Wrong Call
#
# **Research Question:** Which content pages should be prioritized for a content refresh based on their historical performance metrics?
#
# **Decision:** This project aims to improve the decision of which content pages should be refreshed first.
#
# **Action:** The recommendations will be used by content managers or SEO specialists to review and update the pages that are most likely to benefit from a content refresh.
#
# **Cost of a Wrong Recommendation:** If a page that does not need updating is recommended, the team may waste time and resources. If an important page that needs a refresh is not recommended, the organization may miss opportunities to improve content performance and user engagement. Therefore, the results should be used as decision support rather than as automatic decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
# The starter dataset contains 30,000 anonymized content pages with 44 features describing content performance and metadata. The average CTR is 0.51%, the average engagement rate is 2.53%, and the average trend percentage is -4.79%. These observed values indicate variation in content performance, making this dataset suitable for investigating which pages should be prioritized for a content refresh.

# %%
import pandas as pd

# Load the dataset from GitHub
url = "https://raw.githubusercontent.com/maalaaikaa/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

# Basic information
print("Dataset Shape:", df.shape)

# Display column names
print("\nColumns:")
print(df.columns.tolist())

# Display 2–3 useful statistics
if "ctr" in df.columns:
    print(f"\nAverage CTR: {df['ctr'].mean():.2f}")

if "engagement_rate" in df.columns:
    print(f"Average Engagement Rate: {df['engagement_rate'].mean():.2f}")

if "trend_pct" in df.columns:
    print(f"Average Trend Percentage: {df['trend_pct'].mean():.2f}")

# Preview the dataset
print("\nFirst 5 Rows:")
print(df.head())
# Out:
# Dataset Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# Average CTR: 0.51
# Average Engagement Rate: 2.53
# Average Trend Percentage: -4.79
#
# First 5 Rows:
#              content_id          client_id  search_volume  competition  \
# ...

# %% [markdown]
# ## 4 . Careful Words: What I Can and Can't Claim
#
# This project provides **decision support** by identifying patterns **observed** in historical content performance data. The results can help content managers prioritize which pages may be reviewed for a content refresh, but they should not be treated as automatic decisions. The findings are **directional** and based only on the available anonymized dataset. This project **cannot prove** that refreshing content directly causes better search rankings or increased traffic, and it does **not** predict Google's search algorithm or future ranking changes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
